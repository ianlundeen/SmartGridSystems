# %% [markdown]
# Data Exploration

# %%
import pandas as pd

# %%
data = pd.read_csv("../../data/processed/combined_hourly.csv")

# %%
data
# Out:
#                   datetime  load_mw  temperature_c  precipitation_mm  \
# 0      2019-01-01 00:00:00  21934.0          4.525               0.0
# 1      2019-01-01 01:00:00  21188.0          4.475               0.0
# 2      2019-01-01 02:00:00  20613.0          3.475               0.0
# 3      2019-01-01 03:00:00  20298.0          3.500               0.0
# 4      2019-01-01 04:00:00  20338.0          2.025               0.0
# ...                    ...      ...            ...               ...
# 52614  2024-12-31 19:00:00  25087.0          9.800               0.0
# 52615  2024-12-31 20:00:00  24354.0          9.400               0.0
# 52616  2024-12-31 21:00:00  23767.0          8.800               0.0
# 52617  2024-12-31 22:00:00  23011.0          8.600               0.0
# 52618  2024-12-31 23:00:00  22143.0          8.225               0.0
#
#        solar_radiation_wm2  windspeed_ms  humidity_pct  gas_price_mmbtu  \
# ...
